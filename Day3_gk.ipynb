# %%
import matplotlib.pyplot as plt
import numpy as np
import pandas as pd

# %%
x = np.array([3,11,16,23,27,44,48,51,56,67])
y = np.array([13,23,34,29,47,51,55,58,84,89])
z= np.array([9,6,32,36,36,73,98,3,6,43])

# %%
plt.title("my plot ")
plt.xlabel("first value ")
plt.ylabel("second value ")
plt.grid()
plt.xlim(0,100)
plt.ylim(0,100)
plt.xticks(range(0,101,20))
plt.yticks(range(0,101,20))



plt.plot(x,y,label='2023',color='yellow')
plt.plot(x,z,label='2025',color='green')
plt.legend()

# %%
plt.plot(x,z)

# %%
plt.plot(x,y,marker='o',color='blue',ls=':',lw=3,mfc='yellow')

# %%
plt.subplot(1,2,1)
plt.plot(x,y,color="violet")
plt.subplot(1,2,2)
plt.plot(x,z,color="green")

# %%
plt.figure(figsize=(16,9))
plt.title('My first plot')
plt.xlabel('First Value')
plt.ylabel('Second Value')
plt.grid()
plt.plot(x,y,label='2023',color='blue')
plt.plot(x,z,label='2025',color='red')
plt.legend()
plt.savefig("gkplot.png")

# %%
plt.title("gks plot")
plt.xlabel('First Value')
plt.ylabel('Second Value')
plt.grid()
plt.scatter(x,y)

# %%
java = np.array([67,45,62,89,41,59,78,46,81,79,47,65])
python = np.array([62,42,69,91,46,60,74,52,85,82,45,68])
cols=[1,2,1,3,2,1,3,2,3,3,2,1]
plt.title('reSULT')
plt.xlabel('Java Marks')
plt.ylabel('Python Marks')
plt.grid()
plt.scatter(java,python,c=cols)

# %% [markdown]
#  # bar plot,

# %%
enrollment=[104,114,234,566,444,444]
subject = ['Python','PHP','Data Structures','Java','C','OOP']
plt.xlabel('subject')
plt.ylabel('enrolled students')
plt.grid()
plt.bar(subject,enrollment,color='gray')
# Out:
# <BarContainer object of 6 artists>

# %%
plt.barh(subject,enrollment,color='maroon')
# Out:
# <BarContainer object of 6 artists>

# %%
plt.figure(figsize=(10,10))
plt.pie(enrollment ,labels=subject,autopct='%2.2f');

# %% [markdown]
# # univariate analysis

# %% [markdown]
# ## Histogram

# %%
marks =np.array([56,67,72,93,75,45,26,58,65,61,68,47])

# %%
plt.xlabel('Range of Marks')
plt.ylabel('Count')
plt.grid()
plt.xticks(range(0,101,10))
plt.hist(marks ,color='chocolate',bins=range(0,101,10));

# %%
plt.boxplot(marks);

# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt

# %%
df = pd.read_csv('Salary_Data.csv')

# %%
df.shape
# Out:
# (30, 2)

# %%
df.head()
# Out:
#    YearsExperience   Salary
# 0              1.1  39343.0
# 1              1.3  46205.0
# 2              1.5  37731.0
# 3              2.0  43525.0
# 4              2.2  39891.0

# %%
df
# Out:
#     YearsExperience    Salary
# 0               1.1   39343.0
# 1               1.3   46205.0
# 2               1.5   37731.0
# 3               2.0   43525.0
# 4               2.2   39891.0
# 5               2.9   56642.0
# 6               3.0   60150.0
# 7               3.2   54445.0
# 8               3.2   64445.0
# 9               3.7   57189.0
# 10              3.9   63218.0
# 11              4.0   55794.0
# 12              4.0   56957.0
# 13              4.1   57081.0
# 14              4.5   61111.0
# 15              4.9   67938.0
# 16              5.1   66029.0
# 17              5.3   83088.0
# 18              5.9   81363.0
# 19              6.0   93940.0
# 20              6.8   91738.0
# 21              7.1   98273.0
# 22              7.9  101302.0
# 23              8.2  113812.0
# 24              8.7  109431.0
# 25              9.0  105582.0
# 26              9.5  116969.0
# 27              9.6  112635.0
# 28             10.3  122391.0
# 29             10.5  121872.0

# %%
plt.scatter(df['YearsExperience'],df['Salary'])

# %%
x=df['YearsExperience'].values
y=df['Salary']

# %%
x
# Out:
# array([ 1.1,  1.3,  1.5,  2. ,  2.2,  2.9,  3. ,  3.2,  3.2,  3.7,  3.9,
#         4. ,  4. ,  4.1,  4.5,  4.9,  5.1,  5.3,  5.9,  6. ,  6.8,  7.1,
#         7.9,  8.2,  8.7,  9. ,  9.5,  9.6, 10.3, 10.5])

# %%
y
# Out:
# 0      39343.0
# 1      46205.0
# 2      37731.0
# 3      43525.0
# 4      39891.0
# 5      56642.0
# 6      60150.0
# 7      54445.0
# 8      64445.0
# 9      57189.0
# 10     63218.0
# 11     55794.0
# 12     56957.0
# 13     57081.0
# 14     61111.0
# 15     67938.0
# 16     66029.0
# 17     83088.0
# 18     81363.0
# 19     93940.0
# 20     91738.0
# 21     98273.0
# 22    101302.0
# 23    113812.0
# 24    109431.0
# 25    105582.0
# 26    116969.0
# 27    112635.0
# 28    122391.0
# 29    121872.0
# Name: Salary, dtype: float64

# %%
x=x.reshape(30,1)
x
# Out:
# array([[ 1.1],
#        [ 1.3],
#        [ 1.5],
#        [ 2. ],
#        [ 2.2],
#        [ 2.9],
#        [ 3. ],
#        [ 3.2],
#        [ 3.2],
#        [ 3.7],
#        [ 3.9],
#        [ 4. ],
#        [ 4. ],
#        [ 4.1],
#        [ 4.5],
#        [ 4.9],
#        [ 5.1],
#        [ 5.3],
#        [ 5.9],
#        [ 6. ],
#        [ 6.8],
#        [ 7.1],
#        [ 7.9],
#        [ 8.2],
#        [ 8.7],
#        [ 9. ],
#        [ 9.5],
#        [ 9.6],
#        [10.3],
#        [10.5]])

# %% [markdown]
# # import linear regression class

# %%
from sklearn.linear_model import LinearRegression

# %% [markdown]
# ## create object of linear regression

# %%
regressor = LinearRegression()

# %% [markdown]
# ##### train the algorithm

# %%
regressor.fit(x,y)
# Out:
# LinearRegression()

# %% [markdown]
# ## predict on unseen data

# %%
regressor.predict([[15]])
# Out:
# array([167541.63502049])

# %%
regressor.predict([[20]])
# Out:
# array([214791.44662777])

# %%
regressor.predict([[0]])
# Out:
# array([25792.20019867])
